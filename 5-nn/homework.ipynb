# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

# Загружаем датасет Breast Cancer
cancer = load_breast_cancer()

# Создаем DataFrame для удобства работы с данными
cancer_df = pd.DataFrame(data=cancer.data, columns=cancer.feature_names)
cancer_df['target'] = cancer.target

# %%
cancer_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# <h1>Создание Тензора</h1>

# %%
import torch

# Создаем тензор из списка
tensor_a = torch.tensor([1, 2, 3])
print(...)

# Создаем тензор из массива NumPy
import numpy as np
array_b = np.array([4, 5, 6])
tensor_b = torch.tensor(...)
print(...)
# Out:
# tensor([1, 2, 3])
# tensor([4, 5, 6])

# %% [markdown]
# <h1>Основные операции</h1>

# %%
# Сложение
result = ...
print(result)

# Умножение
result = ...
print(result)

# Поэлементное умножение
result = torch.mul(..., ...)
print(result)
# Out:
# tensor([5, 7, 9])
# tensor([ 4, 10, 18])
# tensor([ 4, 10, 18])

# %% [markdown]
# <h1>Индексирование и срезы</h1>

# %%
# Обращение к элементу по индексу
print(...)

# Срез
print(...)

# Индексирование по условию
print(...[tensor_a > 1])
# Out:
# tensor(1)
# tensor([2, 3])
# tensor([2, 3])

# %% [markdown]
# <h1>Операции над матрицами</h1>

# %%
# Умножение матриц
matrix_a = torch.tensor([[1, 2], [3, 4]])
matrix_b = torch.tensor([[5, 6], [7, 8]])
result = torch.mm(..., ...)
print(result)
# Out:
# tensor([[19, 22],
#         [43, 50]])

# %% [markdown]
# <h1>Решение задачи с помощью простой нейросети</h1>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
# Подготовка данных
X = cancer.data
y = cancer.target
# Разбиваем данные на трейн и тест выборки
...

# Нормализация данных
scaler = StandardScaler()
X_train = scaler.fit_transform(...)
X_test = scaler.transform(...)

# %%
# Преобразование в тензоры PyTorch
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = ...
X_test = ...
y_test = ...

# %%
# Определение нейронной сети, можете менять архитектуру как хотите)

class SimpleNN(nn.Module):
    def __init__(self, input_size):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(64, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return ...

# %%
# Создание модели и выбор лосса и оптимизатора
input_size = X_train.shape[1]
model = ....
loss_fn = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=...)

# %%
# Тренировка модели
num_epochs = ...

for epoch in range(num_epochs):
    # Forward pass
    # считаем предсказания
    outputs = ...

    # считаем лосс
    loss = ...

    # обнуляем градиенты оптимизатора
    ...

    # считаем градиенты лосса
    ...

    # делаем шаг оптимизатора
    ...

    # Выводим информацию о процессе обучения
    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [10/50], Loss: 0.1353
# Epoch [20/50], Loss: 0.0740
# Epoch [30/50], Loss: 0.0564
# Epoch [40/50], Loss: 0.0434
# Epoch [50/50], Loss: 0.0342

# %%
# Оценка модели на тестовых данных
with torch.no_grad():
    y_pred = model(...)
    y_pred = (y_pred >= 0.5).float().view(-1)
    accuracy = ...

print(...)
# Out:
# Accuracy on test data: 0.9825
